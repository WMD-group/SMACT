# %% [markdown]
# # Quaternary Oxide Composition Generation with SMACT
# This tutorial demonstrates how to generate a set of quaternary oxide compositions using the SMACT library and a modified `smact_filter` function then prepare the results for machine learning analysis.

# %% [markdown]
# ## Prerequisites
# Before starting, ensure you have the following libraries installed:

# %%
! pip install smact pandas pymatgen matminer
# Out:
# Requirement already satisfied: smact in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (2.6)
# Requirement already satisfied: pandas in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: pymatgen in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (2024.4.13)
# Requirement already satisfied: matminer in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (0.9.2)
# Requirement already satisfied: scipy in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from smact) (1.14.0)
# Requirement already satisfied: numpy<2 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from smact) (1.26.4)
# Requirement already satisfied: spglib in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from smact) (2.5.0)
# Requirement already satisfied: ase in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from smact) (3.23.0)
# Requirement already satisfied: pathos in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from smact) (0.3.2)
# Requirement already satisfied: typing-extensions in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from smact) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: matplotlib>=1.5 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pymatgen) (3.9.1)
# Requirement already satisfied: monty>=2024.2.2 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pymatgen) (2024.7.12)
# Requirement already satisfied: networkx>=2.2 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pymatgen) (3.3)
# Requirement already satisfied: palettable>=3.1.1 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pymatgen) (3.3.3)
# Requirement already satisfied: plotly>=4.5.0 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pymatgen) (5.22.0)
# Requirement already satisfied: pybtex in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pymatgen) (0.24.0)
# Requirement already satisfied: requests in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pymatgen) (2.32.3)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pymatgen) (0.18.6)
# Requirement already satisfied: sympy in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pymatgen) (1.13.1)
# Requirement already satisfied: tabulate in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pymatgen) (0.9.0)
# Requirement already satisfied: tqdm in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pymatgen) (4.66.4)
# Requirement already satisfied: uncertainties>=3.1.4 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pymatgen) (3.2.2)
# Requirement already satisfied: joblib in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pymatgen) (1.4.2)
# Requirement already satisfied: pymongo~=4.5 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from matminer) (4.8.0)
# Requirement already satisfied: scikit-learn~=1.3 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from matminer) (1.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from matplotlib>=1.5->pymatgen) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from matplotlib>=1.5->pymatgen) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from matplotlib>=1.5->pymatgen) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from matplotlib>=1.5->pymatgen) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from matplotlib>=1.5->pymatgen) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from matplotlib>=1.5->pymatgen) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from matplotlib>=1.5->pymatgen) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from plotly>=4.5.0->pymatgen) (8.5.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pymongo~=4.5->matminer) (2.6.1)
# Requirement already satisfied: six>=1.5 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from requests->pymatgen) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from requests->pymatgen) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from requests->pymatgen) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from requests->pymatgen) (2024.7.4)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from ruamel.yaml>=0.17.0->pymatgen) (0.2.8)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from scikit-learn~=1.3->matminer) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from sympy->pymatgen) (1.3.0)
# Requirement already satisfied: ppft>=1.7.6.8 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pathos->smact) (1.7.6.8)
# Requirement already satisfied: dill>=0.3.8 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pathos->smact) (0.3.8)
# Requirement already satisfied: pox>=0.3.4 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pathos->smact) (0.3.4)
# Requirement already satisfied: multiprocess>=0.70.16 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pathos->smact) (0.70.16)
# Requirement already satisfied: PyYAML>=3.01 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pybtex->pymatgen) (6.0.1)
# Requirement already satisfied: latexcodec>=1.0.4 in /Users/rynduma/.pyenv/versions/3.12.0/envs/50ml/lib/python3.12/site-packages (from pybtex->pymatgen) (3.0.0)

# %% [markdown]
# ## Workflow

# %% [markdown]
# ### 1. Import Required Libraries

# %%
"""
This module imports necessary libraries and modules for generating and analyzing
quaternary oxide compositions using SMACT and machine learning techniques.

"""
# Standard library imports
import multiprocessing
from itertools import combinations, product

# Third-party imports
import pandas as pd
from matminer.featurizers import composition as cf
from matminer.featurizers.base import MultipleFeaturizer
from matminer.featurizers.conversions import StrToComposition
from pymatgen.core import Composition

# Local imports
import smact
from smact import screening

"""
Imported modules:
- multiprocessing: For parallel processing capabilities
- itertools: For generating combinations and products
- pandas: For data manipulation and analysis
- matminer: For materials data mining and feature extraction
- pymatgen: For materials analysis
- smact: For structure prediction and analysis of new materials
"""
# Out:
# '\nImported modules:\n- multiprocessing: For parallel processing capabilities\n- itertools: For generating combinations and products\n- pandas: For data manipulation and analysis\n- matminer: For materials data mining and feature extraction\n- pymatgen: For materials analysis\n- smact: For structure prediction and analysis of new materials\n'

# %% [markdown]
# ### 2. Define Elements and Combinations
#
# Select the elements to use in our compositions

# %%
# Define the elements we are interested in
all_el = smact.element_dictionary()
symbol_list = [k for k in all_el.keys()]

# List of elements to exclude
do_not_want = [
    "H", "He", "B", "C", "O", "Ne", "Ar", "Kr", "Tc", "Xe", "Rn",
    "Ac", "Th", "Pa", "U", "Np", "Pu", "Am", "Cm", "Bk", "Cf",
    "Es", "Fm", "Md", "No", "Lr", "Ra", "Fr", "At", "Po", "Pm",
    "Eu", "Tb", "Yb"
]

# Create a list of elements we want to use
good_elements = [all_el[x] for x in symbol_list if x not in do_not_want]

# Generate all possible combinations of 3 elements from good_elements
all_el_combos = combinations(good_elements, 3)

# %% [markdown]
# ### 3. Define SMACT Filtering Function
#
# Create a function to filter element combinations based on SMACT criteria:

# %%
def smact_filter(els):
    """
    Filter element combinations based on SMACT criteria.

    This function takes a combination of elements and applies SMACT
    (Semiconducting Materials from Analogy and Chemical Theory) tests
    to generate potential quaternary oxide compositions.

    Args:
        els (tuple): A tuple containing three Element objects.

    Returns:
        list: A list of tuples, each containing a set of elements and their ratios
              that pass the SMACT criteria.
    """
    all_compounds = []
    elements = [e.symbol for e in els] + ["O"]

    # Get Pauling electronegativities
    paul_a, paul_b, paul_c = (el.pauling_eneg for el in els)
    electronegativities = [paul_a, paul_b, paul_c, 3.44]  # 3.44 is for Oxygen

    # Iterate through all possible oxidation state combinations
    for ox_states in product(*(el.oxidation_states for el in els)):
        ox_states = list(ox_states) + [-2]  # Add oxygen's oxidation state
        
        # Test for charge balance
        cn_e, cn_r = smact.neutral_ratios(ox_states, threshold=8)
        
        if cn_e:
            # Electronegativity test
            if screening.pauling_test(ox_states, electronegativities):
                compound = (elements, cn_r[0])
                all_compounds.append(compound)
    
    return all_compounds

# %% [markdown]
# ### 4. Process Element Combinations
#
# Use multiprocessing to apply the SMACT filter to all element combinations:
#
# Here multiprocessing is used to speed things up (generation of all compositions takes ~40 minutes on a 4GHz Intel core i7 iMac).

# %%
def process_element_combinations(all_el_combos):
    """
    Process all element combinations using multiprocessing.

    This function applies the smact_filter to all element combinations
    using a multiprocessing pool to improve performance.

    Args:
        all_el_combos (iterable): An iterable of element combinations.

    Returns:
        list: A flattened list of all compounds that pass the SMACT criteria.
    """
    with multiprocessing.Pool() as p:
        # Apply smact_filter to all element combinations in parallel
        result = p.map(smact_filter, all_el_combos)

    # Flatten the list of results
    flat_list = [item for sublist in result for item in sublist]
    return flat_list

# Process all element combinations
flat_list = process_element_combinations(all_el_combos)

# Print the number of compositions found
print(f"Number of compositions: {len(flat_list)}")
# Out:
# Process SpawnPoolWorker-13:
# Process SpawnPoolWorker-14:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process SpawnPoolWorker-15:
# Traceback (most recent call last):
# Process SpawnPoolWorker-16:
# Traceback (most recent call last):
# Process SpawnPoolWorker-17:
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-18:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-19:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-20:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-21:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-22:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-23:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-24:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-25:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-26:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-27:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-28:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-29:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-30:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-31:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-32:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-33:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-34:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-35:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-36:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-37:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-38:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-39:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-40:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-41:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-42:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-43:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-44:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-45:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-46:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-47:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-48:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-49:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-50:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-51:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-52:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-53:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-54:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-55:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-56:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-57:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-58:
# Traceback (most recent call last):
# Process SpawnPoolWorker-59:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# Process SpawnPoolWorker-61:
# Traceback (most recent call last):
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Users/rynduma/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/queues.py", line 369, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'smact_filter' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 23
#      20     return flat_list
#      22 # Process all element combinations
# ---> 23 flat_list = process_element_combinations(all_el_combos)
#      25 # Print the number of compositions found
#      26 print(f"Number of compositions: {len(flat_list)}")
#
# Cell In[15], line 16, in process_element_combinations(all_el_combos)
#       2 """
#       3 Process all element combinations using multiprocessing.
#       4
#    (...)
#      12     list: A flattened list of all compounds that pass the SMACT criteria.
#      13 """
#      14 with multiprocessing.Pool() as p:
#      15     # Apply smact_filter to all element combinations in parallel
# ---> 16     result = p.map(smact_filter, all_el_combos)
#      18 # Flatten the list of results
#      19 flat_list = [item for sublist in result for item in sublist]
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/threading.py:634, in Event.wait(self, timeout)
#     632 signaled = self._flag
#     633 if not signaled:
# --> 634     signaled = self._cond.wait(timeout)
#     635 return signaled
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/threading.py:334, in Condition.wait(self, timeout)
#     332 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     333     if timeout is None:
# --> 334         waiter.acquire()
#     335         gotit = True
#     336     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### 5. Generate Pretty Formulas
#
# This step turns the generated compositions into pretty formulas, again using multiprocessing. There should be ~1.1M unique formulas.

# %%
def comp_maker(comp):
    """
    Convert a composition tuple to a pretty formula string.

    Args:
        comp (tuple): A tuple containing two lists - elements and their amounts.

    Returns:
        str: The reduced formula of the composition as a string.
    """
    # Create a list to store elements and their amounts
    form = []
    # Iterate through elements and their amounts
    for el, ammt in zip(comp[0], comp[1]):
        form.append(el)
        form.append(ammt)
    # Join all elements into a single string
    form = "".join(str(e) for e in form)
    # Convert to a Composition object and get the reduced formula
    pmg_form = Composition(form).reduced_formula
    return pmg_form


# Use multiprocessing to apply comp_maker to all compositions in flat_list
with multiprocessing.Pool() as p:
    pretty_formulas = p.map(comp_maker, flat_list)

# Create a list of unique formulas
unique_pretty_formulas = list(set(pretty_formulas))
# Print the number of unique composition formulas
print(f"Number of unique compositions formulas: {len(unique_pretty_formulas)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 26
#      24 # Use multiprocessing to apply comp_maker to all compositions in flat_list
#      25 with multiprocessing.Pool() as p:
# ---> 26     pretty_formulas = p.map(comp_maker, flat_list)
#      28 # Create a list of unique formulas
#      29 unique_pretty_formulas = list(set(pretty_formulas))
#
# NameError: name 'flat_list' is not defined

# %% [markdown]
# ### 6. Create DataFrame and Add Descriptors
#
# Create a DataFrame from the unique formulas and add composition-based descriptors:

# %%
# Create a DataFrame from the unique pretty formulas
new_data = pd.DataFrame(unique_pretty_formulas).rename(
    columns={0: "pretty_formula"}
)

# Remove any duplicate formulas to ensure uniqueness
new_data = new_data.drop_duplicates(subset="pretty_formula")

# Display summary statistics of the DataFrame
# This will show count, unique values, top value, and its frequency
# new_data.describe()


# Add descriptor columns
# This will take a little time as we have over 1 million rows

def add_descriptors(data):
    """
    Add composition-based descriptors to the dataframe.

    This function converts formula strings to composition objects and calculates
    various features using matminer's composition featurizers.

    Args:
        data (pd.DataFrame): DataFrame containing 'pretty_formula' column.

    Returns:
        pd.DataFrame: DataFrame with added descriptor columns.
    """
    # Convert formula strings to composition objects
    str_to_comp = StrToComposition(target_col_id="composition_obj")
    str_to_comp.featurize_dataframe(data, col_id="pretty_formula")

    # Initialize multiple featurizers
    feature_calculators = MultipleFeaturizer(
        [
            cf.Stoichiometry(),
            cf.ElementProperty.from_preset("magpie"),
            cf.ValenceOrbital(props=["avg"]),
            cf.IonProperty(fast=True),
            cf.BandCenter(),
            cf.AtomicOrbitals(),
        ]
    )

    # Calculate features
    feature_calculators.featurize_dataframe(data, col_id="composition_obj")
    
    # If you need to use feature_labels later, uncomment the following line:
    # feature_labels = feature_calculators.feature_labels()

    return data

# Apply the function to add descriptors
new_data = add_descriptors(new_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Create a DataFrame from the unique pretty formulas
# ----> 2 new_data = pd.DataFrame(unique_pretty_formulas).rename(
#       3     columns={0: "pretty_formula"}
#       4 )
#       6 # Remove any duplicate formulas to ensure uniqueness
#       7 new_data = new_data.drop_duplicates(subset="pretty_formula")
#
# NameError: name 'unique_pretty_formulas' is not defined

# %% [markdown]
# ### 7. Save Results to a CSV File

# %%
# Save as .csv file
new_data.to_csv("All_oxide_comps_dataframe_featurized.csv", chunksize=10000)

# %% [markdown]
# # Reproducing Results
#
# To reproduce these results:
#
# Ensure all required libraries are installed.
#
# Copy and run the code snippets in order.
#
# Be patient, as the process can take several hours depending on your hardware.
#
# The final output will be a CSV file named "All_oxide_comps_dataframe_featurized.csv"
# containing all generated compositions with their calculated features.
#
# Note: The exact number of compositions may vary slightly due to the nature of parallel processing and potential updates to the SMACT library
